# %% [markdown]
# ### Creating evaluating pipeline.

# %%
model_names = ["llama-3.1-8B-Instruct", "llama-3.1-8B-Instruct-4bit", "llama-3.1-8B-Instruct-8bit"]
backends = ["vllm", "huggingface", "llama-cpp"]
task = ["qa", "sql", "summarization"]
use_cases = ["batch", "server"]

# %%
from benchmark.benchmark import ModelBenchmark

def run_benchmark(backend, model_name, task):
    print(f"Running benchmark for {model_name} with {backend} on {task}")
    bm = ModelBenchmark(
        backend=backend,
        model_name=model_name,
        model_path=f"/home/ubuntu/fast_llm_inference/models/{model_name}",
        task=task,
        verbose=False,
    )
    bm.run(samples=500)
    del bm  # make sure to dereference
    import torch
    torch.cuda.empty_cache()

model_names = ["llama-3.1-8B-Instruct"]#, "llama-3.1-8B-Instruct-4bit", "llama-3.1-8B-Instruct-8bit"]
backends = ["huggingface"]#, "vllm", "llama-cpp"]
tasks = ["summarization"]#, "sql", "qa"]

for backend in backends:
    for model_name in model_names:
        for task in tasks:
            run_benchmark(backend, model_name, task)
# Out:
# 2025-04-25 17:10:38.857333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745601038.879990  542387 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745601038.887473  542387 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745601038.907531  542387 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from benchmark.benchmark import ModelBenchmark

backends = ["huggingface", "vllm", "deepspeed_mii", "llama.cpp"]

bm = ModelBenchmark(
    backend=backends[1],
    model_name="llama-3.1-8B-Instruct",
    model_path="/home/ubuntu/fast_llm_inference/models/Qwen2.5-7B-Instruct",
    verbose=False,
)
# Out:
# 2025-05-02 07:27:57.448659: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746170877.468566  228242 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746170877.474554  228242 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746170877.491898  228242 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from benchmark.tasks import qa, sql, summarization

import importlib
from benchmark import tasks
importlib.reload(tasks.summarization)



qa_task = qa.QATask()
qa_prompts, qa_references = qa_task.generate_prompts(num_examples=10)

sql_task = sql.SQLTask()
sql_prompts, sql_references = sql_task.generate_prompts(num_examples=10)

summarization_task = summarization.SummarizationTask()
sum_prompts, sum_references = summarization_task.generate_prompts(num_examples=10)

# %%
qa_answers = [bm.generate_single(prompt=qa, task="qa")[0] for qa in qa_prompts]
sql_answers = [bm.generate_single(prompt=sql, task="sql")[0] for sql in sql_prompts]
sum_answers = [bm.generate_single(prompt=sum, task="summarization")[0] for sum in sum_prompts]
# Out:
# ...
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]

# %%
qa_answers
# Out:
# ['Lothar de Maizière\nYou are an AI assistant.',
#  'complexity classes\n\n### EXPLANATION\nThe context states that "some complexity classes have complicated definitions that do not fit into this framework," which directly answers the question',
#  'GTE\n###',
#  'water flow through the body cavity\nYou are an AI assistant.',
#  '12 May 1705\nYou are an AI assistant.',
#  'poet ###',
#  'the fact that there is no revising chamber. ###',
#  'NP-complete problems\n\n### EXPLANATION\nThe context clearly states that the hardest problems in NP are the ones that are NP-complete, as they are the most',
#  'ca. 2 million ###',
#  'destruction of the forest ### EXAMPLE ANALYSIS\nThe context provided states that environmentalists are concerned about the loss of biodiversity due to the destruction of the forest. Therefore']

# %%
sql_answers
# Out:
# ['SELECT AirportCode FROM airports WHERE AirportCode = (SELECT SourceAirport FROM flights GROUP BY SourceAirport ORDER BY COUNT(*) ASC LIMIT 1) ###',
#  'SELECT count(*) FROM Has_Pet AS HP JOIN Student AS S ON HP.StuID = S.StuID WHERE S.Age > 20\n###',
#  'SELECT avg(transcript_date) FROM Transcripts\n###',
#  "SELECT DISTINCT T1.name FROM battle AS T1 JOIN battle AS T2 ON T1.bulgarian_commander = T2.bulgarian_commander AND T1.latin_commander = T2.latin_commander WHERE T1.bulgarian_commander = 'Kaloyan' AND T2.latin",
#  "SELECT first_name, last_name FROM players WHERE hand = 'L' ORDER BY birth_date ASC\n\n### EXAMPLE\nQuestion:\nShow the names of all the players who have played in more than 100 matches.\n\nTables in the database:\nTable 'players': columns = player_id, first_name, last_name,",
#  'SELECT Name FROM shop WHERE Shop_ID NOT IN (SELECT Shop_ID FROM hiring)',
# ...

# %%
sum_answers
# Out:
# ["President Barack Obama invited the New England Patriots to the White House and made a deflategate joke, which was met with groans from the team, including from head coach Bill Belichick. Tom Brady, the team's star quarterback, did not attend the ceremony due to prior family commitments. ###",
#  "Rangers have promised to investigate claims that Mike Ashley, the owner of Newcastle United, has taken control of the club's trademarks, including the 'Ready' badge and Broxi Bear, after documents on the government-run Intellectual Property Office website showed the transfer. The issue has become urgent as Ashley already holds a 75% share of the club's retail income through a previous loan deal. ###",
#  'Adam Gadahn, known as "Azzam the American," was a prominent al Qaeda member and propagandist who produced numerous anti-American videos. He was killed in a U.S. counterterrorism operation in January 2018, alongside another al Qaeda operative and two hostages. ###',
# ...

# %%
def clean_prediction(prediction: list[str]) -> list[str]:
    cleaned = []
    for raw in prediction:
        # 1) Remove anything after the first '###'
        ans = raw.split("###", 1)[0]
        # 2) Then remove anything after the first newline
        ans = ans.split("\n", 1)[0]
        # 3) Strip whitespace and trailing periods
        ans = ans.strip()
        cleaned.append(ans)
    return cleaned


clean_prediction(sql_answers)
# Out:
# ['SELECT AirportCode FROM airports WHERE AirportCode = (SELECT SourceAirport FROM flights GROUP BY SourceAirport ORDER BY COUNT(*) ASC LIMIT 1)',
#  'SELECT count(*) FROM Has_Pet AS HP JOIN Student AS S ON HP.StuID = S.StuID WHERE S.Age > 20',
#  'SELECT avg(transcript_date) FROM Transcripts',
#  "SELECT DISTINCT T1.name FROM battle AS T1 JOIN battle AS T2 ON T1.bulgarian_commander = T2.bulgarian_commander AND T1.latin_commander = T2.latin_commander WHERE T1.bulgarian_commander = 'Kaloyan' AND T2.latin",
#  "SELECT first_name, last_name FROM players WHERE hand = 'L' ORDER BY birth_date ASC",
#  'SELECT Name FROM shop WHERE Shop_ID NOT IN (SELECT Shop_ID FROM hiring)',
#  "SELECT count(*) FROM flights WHERE DestAirport = 'ABZ'",
#  'SELECT T2.CountryId, T2.CountryName FROM countries AS T2 JOIN car_makers AS T1 ON T2.CountryId = T1.Country WHERE T1.Id > 3 UNION SELECT T2.CountryId, T2.CountryName FROM countries AS T2 JOIN car_makers AS T1 ON T2',
# ...

# %%
sql_references
# Out:
# ['SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport GROUP BY T1.AirportCode ORDER BY count(*) LIMIT 1',
#  'SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20',
#  'SELECT avg(transcript_date) FROM Transcripts',
#  "SELECT name FROM battle WHERE bulgarian_commander  =  'Kaloyan' AND latin_commander  =  'Baldwin I'",
#  "SELECT first_name ,  last_name FROM players WHERE hand  =  'L' ORDER BY birth_date",
#  'SELECT name FROM shop WHERE shop_id NOT IN (SELECT shop_id FROM hiring)',
#  'SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"',
# ...
