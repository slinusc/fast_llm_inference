# %%
# !ollama run mistral

# %%
import requests

# Define the API endpoint and model
url = "http://localhost:11434/api/generate"
model = "llama3.1:8b"

# Define your prompt
payload = {
    "model": model,
    "prompt": "What's the capital of Japan?",
    "stream": False  # Set to True if you want streaming responses
}

# Send the POST request to Ollama's API
response = requests.post(url, json=payload)

# Parse the response JSON
if response.status_code == 200:
    result = response.json()
    print(result['response'])  # The actual text output
else:
    print("Error:", response.status_code, response.text)
# Out:
# The capital of Japan is Tokyo.

# %%
import time

test_prompts = [
    "Explain the significance of transformer models in NLP.",
    "What are the main benefits of renewable energy?",
    "How does the immune system work?",
    "What is the capital of France?",
    "What is the best way to cook a steak?"
]

start = time.time()

for prompt in test_prompts:
    payload = {
        "model": model,
        "prompt": prompt,
        "stream": False
    }
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        result = response.json()
        print(result['response'])
    else:
        print("Error:", response.status_code, response.text)

end = time.time()

print("Time taken:", end - start, "seconds")
# Out:
# Transformer models have revolutionized the field of Natural Language Processing (NLP) and have become a cornerstone of many state-of-the-art models. Here's why:
#
# **What are Transformer models?**
#
# The Transformer model is a type of neural network architecture introduced by Vaswani et al. in 2017. It's designed to process sequential data, such as text, by using self-attention mechanisms to weigh the importance of different input elements relative to each other.
#
# **Key features that make Transformers significant:**
#
# 1. **Self-Attention**: Unlike traditional recurrent neural networks (RNNs) and convolutional neural networks (CNNs), which rely on sequential processing of data, Transformer models use self-attention mechanisms to attend to all positions in the sequence simultaneously and weigh their importance.
# 2. **Parallelization**: Transformers can process multiple input elements in parallel, making them significantly faster than RNNs and CNNs, which are sequential by nature.
# 3. **Multi-head attention**: The Transformer model uses multi-head attention, which allows it to jointly attend to information from different representation subspaces at different positions.
#
# **Significance of Transformers in NLP:**
#
# 1. **State-of-the-art performance**: Transformer models have achieved state-of-the-art results on many NLP benchmarks, including machine translation, question answering, text classification, and sentiment analysis.
# 2. **Flexibility**: Transformers can be fine-tuned for a wide range of tasks with minimal modifications, making them highly versatile.
# 3. **Efficiency**: The parallelization capabilities of Transformer models make them computationally efficient compared to traditional RNNs and CNNs.
# 4. **Handling long-range dependencies**: Self-attention mechanisms in Transformers enable the model to handle long-range dependencies in text data more effectively than RNNs and CNNs.
#
# **Applications of Transformers:**
#
# 1. **Machine translation**: Transformer-based models, such as Google's BERT and RoBERTa, have set new benchmarks for machine translation tasks.
# 2. **Question answering**: Transformers have been used in question-answering systems to improve their ability to extract relevant information from large text datasets.
# 3. **Sentiment analysis**: Transformers have achieved state-of-the-art results on sentiment analysis tasks, such as predicting the emotional tone of a given text.
#
# **Challenges and limitations:**
#
# 1. **Scalability**: While Transformer models are highly efficient, they can be computationally expensive for very large-scale applications.
# 2. **Training complexity**: Training Transformer models requires significant computational resources and expertise in NLP and deep learning.
#
# In summary, the significance of transformer models lies in their ability to process sequential data efficiently, parallelize computations, and achieve state-of-the-art results on various NLP tasks. However, they also present challenges related to scalability and training complexity, which need to be addressed in future research directions.
# The main benefits of renewable energy are:
#
# 1. **Reduced Greenhouse Gas Emissions**: Renewable energy sources, such as solar and wind power, emit significantly less greenhouse gases (GHGs) than fossil fuels, contributing to climate change.
# 2. **Energy Independence**: By generating electricity locally, communities can reduce their dependence on imported fuels, enhancing energy security and reducing the impact of price volatility.
# 3. **Improved Air Quality**: Renewable energy reduces air pollution from burning fossil fuels, improving public health and quality of life, particularly in urban areas.
# 4. **Sustainable Resource Use**: Renewable energy sources are generally more sustainable than finite resources like coal, oil, and gas, which will eventually run out.
# 5. **Job Creation and Economic Growth**: The renewable energy industry is creating new job opportunities and driving economic growth, both locally and globally.
# 6. **Water Conservation**: Many renewable energy technologies require minimal water consumption compared to traditional fossil fuel-based power plants.
# 7. **Lower Operating Costs**: Renewable energy systems often have lower maintenance costs than traditional power plants, reducing the overall cost of electricity generation.
# 8. **Diversified Energy Mix**: Integrating renewable energy into the energy mix reduces dependence on a single energy source, enhancing grid resilience and reliability.
# 9. **Enhanced Energy Security**: Renewable energy can be generated locally, reducing the risks associated with global market fluctuations and supply chain disruptions.
# 10. **Environmental Stewardship**: Renewable energy promotes environmental sustainability by minimizing waste, preserving natural resources, and protecting ecosystems.
#
# Some of the most promising renewable energy sources are:
#
# 1. Solar power (Photovoltaic (PV) panels)
# 2. Wind power
# 3. Hydroelectric power
# 4. Geothermal energy
# 5. Biomass energy (e.g., biofuels from organic matter)
#
# As the world transitions towards a low-carbon economy, renewable energy is playing an increasingly important role in meeting global energy demands while mitigating climate change and promoting sustainable development.
# The immune system is a complex and fascinating network of cells, tissues, and organs that work together to defend the body against infections, diseases, and foreign substances. Here's an overview of how it works:
#
# **The Four Main Functions of the Immune System:**
#
# 1. **Recognition**: The immune system recognizes and identifies specific pathogens (bacteria, viruses, fungi, etc.) or foreign substances.
# 2. **Activation**: When a pathogen is recognized, the immune system activates various cells and mechanisms to fight against it.
# 3. **Elimination**: The immune system works to eliminate the pathogen from the body.
# 4. **Memory**: After an infection has been cleared, the immune system retains "memory" of the pathogen, allowing for a faster and more effective response if it is encountered again.
#
# **Key Players in the Immune System:**
#
# 1. **White Blood Cells (Leukocytes)**:
# 	* Neutrophils: kill bacteria and other pathogens
# 	* Lymphocytes (B cells and T cells): recognize and remember specific pathogens
# 	* Monocytes: mature into macrophages, which engulf and digest foreign particles
# 2. **Macrophages**: large phagocytic cells that engulf and digest foreign particles and cellular debris.
# 3. **Dendritic Cells**: specialized antigen-presenting cells (APCs) that process and present antigens to T cells.
# 4. **Lymphoid Organs**:
# 	* Spleen: filters blood, stores red blood cells, and hosts immune cells
# 	* Lymph nodes: filter lymphatic fluid, trap pathogens, and activate immune responses
# 	* Thymus (in children): matures T cells
#
# **The Immune Response:**
#
# 1. **Innate Immunity**: the immediate response to a pathogen, mediated by phagocytes and other components of innate immunity.
# 2. **Adaptive Immunity**: the specific response to a pathogen, mediated by T and B cells, which recognize and remember specific pathogens.
#
# **How it Works:**
#
# 1. A pathogen enters the body through various routes (e.g., skin, respiratory tract).
# 2. The immune system recognizes the pathogen through pattern recognition receptors (e.g., Toll-like receptors) on immune cells.
# 3. Activated immune cells (e.g., neutrophils, macrophages) release chemical signals (cytokines and chemokines) to recruit other immune cells to the site of infection.
# 4. Immune cells recognize and engulf pathogens through phagocytosis or other mechanisms.
# 5. T and B cells interact with APCs (dendritic cells) to process antigens and activate specific responses.
#
# **The Three Stages of an Immune Response:**
#
# 1. **Inflammation**: immune response is triggered, leading to the recruitment of immune cells to the site of infection.
# 2. **Proliferation**: activated T and B cells proliferate and differentiate into effector cells that eliminate the pathogen.
# 3. **Resolution**: the inflammatory response is resolved as pathogens are cleared, and tissue damage is repaired.
#
# **Other Key Concepts:**
#
# 1. **Immune tolerance**: the suppression of immune responses to prevent autoimmunity or inflammation.
# 2. **Immunodeficiency**: a weakened immune system that makes individuals more susceptible to infections.
# 3. **Immunization**: the deliberate introduction of antigens (e.g., vaccines) to stimulate an immune response.
#
# This is a simplified overview, but I hope it gives you a sense of how the immune system works!
# The capital of France is Paris.
# Cooking a steak can be an art, and there are various methods to achieve perfection. Here's a comprehensive guide to help you choose the best way to cook your steak:
#
# **Popular cooking methods:**
#
# 1. **Grilling**: Grilling adds a nice char to the outside while locking in juices. Preheat your grill to medium-high heat (400°F/200°C). Use a cast-iron skillet or grilling mat for even cooking.
# 2. **Pan-searing**: Pan-searing is a great way to cook steaks with a crispy crust and tender interior. Heat a skillet over high heat (450°F/230°C) with some oil, then add the steak.
# 3. **Oven broiling**: Broiling is a dry-heat method that's perfect for achieving a nice sear on the outside while cooking the steak evenly throughout. Preheat your oven to 400°F (200°C).
# 4. **Sous vide**: Sous vide uses precision temperature control to cook the steak evenly and consistently. This method produces tender, flavorful results.
#
# **Best techniques:**
#
# 1. **Searing**: For a crispy crust, sear the steak at high heat for 2-3 minutes per side.
# 2. **Resting**: After cooking, let the steak rest for 5-10 minutes to allow the juices to redistribute and relax the fibers.
# 3. **Doneness checks**:
# 	* Rare: Cook for 3-4 minutes per side (internal temperature: 120°F/49°C).
# 	* Medium-rare: Cook for 4-5 minutes per side (internal temperature: 130°F/54°C).
# 	* Medium: Cook for 5-6 minutes per side (internal temperature: 140°F/60°C).
#
# **Additional tips:**
#
# 1. **Choose the right cut**: Opt for a high-quality, tender steak like ribeye, sirloin, or filet mignon.
# 2. **Seasoning**: Salt and pepper are essential; consider adding other seasonings or marinades to enhance flavor.
# 3. **Oil temperature**: Use a thermometer to ensure your oil is at the right temperature (400°F/200°C) for pan-searing.
# 4. **Don't press down**: Resist the temptation to press down on the steak with your spatula, as this can squeeze out juices and create a tough texture.
#
# **The perfect steak recipe:**
#
# Here's a simple pan-seared ribeye recipe:
#
# Ingredients:
#
# * 1 (1-2 pound) ribeye steak
# * Salt and pepper
# * 2 tablespoons olive oil
# * 2 cloves garlic, minced
#
# Instructions:
#
# 1. Preheat skillet to 450°F (230°C).
# 2. Season the steak with salt, pepper, and garlic.
# 3. Add oil to the skillet and sear the steak for 2-3 minutes per side.
# 4. Finish cooking in the oven at 400°F (200°C) for an additional 5-10 minutes or until desired doneness.
# 5. Let rest for 5-10 minutes before serving.
#
# Remember, practice makes perfect! Experiment with different methods and techniques to find your ideal steak-cooking style.
# Time taken: 57.729230880737305 seconds
